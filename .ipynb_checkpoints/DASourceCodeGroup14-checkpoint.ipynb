# %% [markdown]
# #### **Install these in command prompt before execution**

# %%
# !pip install pandas
# !pip install numpy==2.2.0 
# !pip install scikit-learn
# !pip install matplotlib
# !pip install seaborn 
# !pip install missingno
# !pip install umap-learn
# !pip install tabulate
# Out:
# Requirement already satisfied: pandas in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting numpy==2.2.0
#   Using cached numpy-2.2.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.2.0-cp312-cp312-win_amd64.whl (12.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# Successfully installed numpy-2.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.2.0 which is incompatible.
# Requirement already satisfied: scikit-learn in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: missingno in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from missingno) (2.2.0)
# Requirement already satisfied: matplotlib in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from missingno) (3.10.1)
# Requirement already satisfied: scipy in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from missingno) (1.15.2)
# Requirement already satisfied: seaborn in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from missingno) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib->missingno) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib->missingno) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib->missingno) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib->missingno) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib->missingno) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib->missingno) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from matplotlib->missingno) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from seaborn->missingno) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from pandas>=1.2->seaborn->missingno) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: umap-learn in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (0.5.7)
# Requirement already satisfied: numpy>=1.17 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from umap-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from umap-learn) (1.15.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from umap-learn) (1.6.1)
# Requirement already satisfied: numba>=0.51.2 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from umap-learn) (0.61.0)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from numba>=0.51.2->umap-learn) (0.44.0)
# Collecting numpy>=1.17 (from umap-learn)
#   Using cached numpy-2.1.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: joblib>=0.11 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)
# Requirement already satisfied: colorama in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (from tqdm->umap-learn) (0.4.6)
# Using cached numpy-2.1.3-cp312-cp312-win_amd64.whl (12.6 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.0
#     Uninstalling numpy-2.2.0:
#       Successfully uninstalled numpy-2.2.0
# Successfully installed numpy-2.1.3
# Requirement already satisfied: tabulate in c:\users\leong jing feng\anaconda3\envs\da_project\lib\site-packages (0.9.0)

# %% [markdown]
# #### **Load & Combine all Data**

# %%
import pandas as pd

file_paths = [f'dataset/uwb_dataset_part{i}.csv' for i in range(1, 8)]
environments = ['Office 1', 'Office 2', 'Small Apartment', 
                'Small Workshop', 'Kitchen with a living room', 
                'Bedroom', 'Boiler room']

data_parts = [pd.read_csv(file_path, header=0).assign(Environment=env) 
              for file_path, env in zip(file_paths, environments)]

combined_data_with_env = pd.concat(data_parts, ignore_index=True)

# %%
print(combined_data_with_env.head())
print(f"Combined dataset shape: {combined_data_with_env.shape}")

print(combined_data_with_env['Environment'].value_counts())

for env, part in zip(environments, data_parts):
    print(f"{env} shape: {part.shape}")
# Out:
#    NLOS  RANGE  FP_IDX  FP_AMP1  FP_AMP2  FP_AMP3  STDEV_NOISE  CIR_PWR  \
# 0   0.0   3.90   745.0  18712.0  10250.0  11576.0         64.0  11855.0
# 1   0.0   0.66   749.0  11239.0   6313.0   4712.0         64.0  18968.0
# 2   1.0   7.86   746.0   4355.0   5240.0   3478.0         60.0  14699.0
# 3   1.0   3.48   750.0   8502.0   8416.0   5890.0         76.0   8748.0
# 4   0.0   1.19   746.0  17845.0  18095.0  12058.0         68.0  11380.0
#
#    MAX_NOISE  RXPACC  ...  CIR1007  CIR1008  CIR1009  CIR1010  CIR1011  \
# 0      967.0   611.0  ...    458.0    183.0    158.0    198.0     87.0
# 1     1133.0   447.0  ...    334.0    290.0    228.0    187.0    213.0
# 2      894.0   723.0  ...    373.0    224.0    174.0    124.0    329.0
# 3     1127.0  1024.0  ...    173.0    198.0    160.0    434.0    397.0
# 4     1744.0   276.0  ...    209.0    242.0    296.0     87.0    178.0
#
#    CIR1012  CIR1013  CIR1014  CIR1015  Environment
# 0    296.0    505.0    307.0      0.0     Office 1
# 1    202.0     89.0    103.0      0.0     Office 1
# 2    207.0     96.0    218.0      0.0     Office 1
# 3    290.0    155.0    342.0    256.0     Office 1
# 4    314.0    247.0    292.0    256.0     Office 1
#
# [5 rows x 1032 columns]
# Combined dataset shape: (42000, 1032)
# Environment
# Office 1                      6000
# Office 2                      6000
# Small Apartment               6000
# Small Workshop                6000
# Kitchen with a living room    6000
# Bedroom                       6000
# Boiler room                   6000
# Name: count, dtype: int64
# Office 1 shape: (6000, 1032)
# Office 2 shape: (6000, 1032)
# Small Apartment shape: (6000, 1032)
# Small Workshop shape: (6000, 1032)
# Kitchen with a living room shape: (6000, 1032)
# Bedroom shape: (6000, 1032)
# Boiler room shape: (6000, 1032)

# %%
for i, part in enumerate(data_parts, start=1):
    print(f"Part {i} shape: {part.shape}")
    
print(f"Combined dataset shape: {combined_data_with_env.shape}")
print(combined_data_with_env.head())
# Out:
# Part 1 shape: (6000, 1032)
# Part 2 shape: (6000, 1032)
# Part 3 shape: (6000, 1032)
# Part 4 shape: (6000, 1032)
# Part 5 shape: (6000, 1032)
# Part 6 shape: (6000, 1032)
# Part 7 shape: (6000, 1032)
# Combined dataset shape: (42000, 1032)
#    NLOS  RANGE  FP_IDX  FP_AMP1  FP_AMP2  FP_AMP3  STDEV_NOISE  CIR_PWR  \
# 0   0.0   3.90   745.0  18712.0  10250.0  11576.0         64.0  11855.0
 'CIR337', 'CIR338', 'CIR339', 'CIR340', 'CIR341', 'CIR342', 'CIR343', 'CIR344', 'CIR345', 'CIR346', 'CIR347', 'CIR348', 'CIR349', 'CIR350', 'CIR351', 'CIR352', 'CIR353', 'CIR354', 'CIR355', 'CIR356', 'CIR357', 'CIR358', 'CIR359', 'CIR360', 'CIR361', 'CIR362', 'CIR363', 'CIR364', 'CIR365', 'CIR366', 'CIR367', 'CIR368', 'CIR369', 'CIR370', 'CIR371', 'CIR372', 'CIR373', 'CIR374', 'CIR375', 'CIR376', 'CIR377', 'CIR378', 'CIR379', 'CIR380', 'CIR381', 'CIR382', 'CIR383', 'CIR384', 'CIR385', 'CIR386', 'CIR387', 'CIR388', 'CIR389', 'CIR390', 'CIR391', 'CIR392', 'CIR393', 'CIR394', ...

# %% [markdown]
# #### **Dataset Verification**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Verify total number of samples
print("\n=== DATA INTEGRITY CHECK ===")
print(f"Total number of samples: {combined_data_with_env.shape[0]}")
print(f"Expected samples: 42,000")
if combined_data_with_env.shape[0] == 42000:
    print("Sample count matches expected total")
else:
    print(f"Sample count mismatch. Found {combined_data_with_env.shape[0]} instead of 42,000")
    
plt.figure(figsize=(10, 5))
counts = [combined_data_with_env.shape[0], 42000]
labels = ['Actual', 'Expected']
colors = ['#3498db' if counts[0] == counts[1] else ['#e74c3c', '#2ecc71']]

bar = plt.bar(labels, counts, color=colors)
plt.axhline(y=42000, color='r', linestyle='--', alpha=0.5)
plt.title('Sample Count Check', fontsize=14)
plt.ylabel('Number of Samples', fontsize=12)
for i, count in enumerate(counts):
    plt.text(i, count + 500, f"{count:,}", ha='center', fontsize=11)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# === DATA INTEGRITY CHECK ===
# Total number of samples: 42000
# Expected samples: 42,000
# Sample count matches expected total

# %%
# 2. Check class balance
class_counts = combined_data_with_env['NLOS'].value_counts()
print("\n=== CLASS BALANCE CHECK ===")
print(class_counts)
print(f"LOS percentage: {class_counts.get(0, 0) / combined_data_with_env.shape[0] * 100:.2f}%")
print(f"NLOS percentage: {class_counts.get(1, 0) / combined_data_with_env.shape[0] * 100:.2f}%")

if abs(class_counts.get(0, 0) - class_counts.get(1, 0)) < combined_data_with_env.shape[0] * 0.01:
    print("Class balance is approximately 50/50")
else:
    print("Class imbalance detected")

plt.figure(figsize=(10, 6))
class_labels = ['LOS (0)', 'NLOS (1)']
class_sizes = [class_counts.get(0, 0), class_counts.get(1, 0)]
class_percentages = [count / combined_data_with_env.shape[0] * 100 for count in class_sizes]

plt.pie(class_sizes, labels=class_labels, 
        autopct='%1.1f%%', startangle=90, 
        colors=['#3498db', '#e74c3c'],
        explode=(0.05, 0.05), shadow=True, 
        textprops={'fontsize': 12})
plt.axis('equal')
plt.title('Class Distribution', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# === CLASS BALANCE CHECK ===
# NLOS
# 0.0    21000
# 1.0    21000
# Name: count, dtype: int64
# LOS percentage: 50.00%
# NLOS percentage: 50.00%
# Class balance is approximately 50/50

# %%
# 4. Check data formatting (sample check)
print("\n=== DATA FORMAT CHECK ===")
print("Data types:")
pd.set_option('display.max_rows', None)
print(combined_data_with_env.dtypes)
pd.reset_option('display.max_rows')
# Out:
# === DATA FORMAT CHECK ===
# Data types:
# NLOS           float64
# RANGE          float64
# FP_IDX         float64
# FP_AMP1        float64
# FP_AMP2        float64
# FP_AMP3        float64
# STDEV_NOISE    float64
# CIR_PWR        float64
# MAX_NOISE      float64
# RXPACC         float64
# CH             float64
# FRAME_LEN      float64
# PREAM_LEN      float64
# BITRATE        float64
# PRFR           float64
# CIR0           float64
# CIR1           float64
# CIR2           float64
# CIR3           float64
# CIR4           float64
# CIR5           float64
# CIR6           float64
# CIR7           float64
# CIR8           float64
# CIR9           float64
# CIR10          float64
# CIR11          float64
# CIR12          float64
# CIR13          float64
# CIR14          float64
# CIR15          float64
# CIR16          float64
# CIR17          float64
# CIR18          float64
# CIR19          float64
# CIR20          float64
# CIR21          float64
# CIR22          float64
# CIR23          float64
# CIR24          float64
# CIR25          float64
# CIR26          float64
# CIR27          float64
# CIR28          float64
# CIR29          float64
# CIR30          float64
# CIR31          float64
# CIR32          float64
# CIR33          float64
# CIR34          float64
# CIR35          float64
# CIR36          float64
# CIR37          float64
# CIR38          float64
# CIR39          float64
# CIR40          float64
# CIR41          float64
# CIR42          float64
# CIR43          float64
# CIR44          float64
# CIR45          float64
# CIR46          float64
# CIR47          float64
# CIR48          float64
# CIR49          float64
# CIR50          float64
# CIR51          float64
# CIR52          float64
# CIR53          float64
# CIR54          float64
# CIR55          float64
# CIR56          float64
# CIR57          float64
# CIR58          float64
# CIR59          float64
# CIR60          float64
# CIR61          float64
# CIR62          float64
# CIR63          float64
# CIR64          float64
# CIR65          float64
# CIR66          float64
# CIR67          float64
# CIR68          float64
# CIR69          float64
# CIR70          float64
# CIR71          float64
# CIR72          float64
# CIR73          float64
# CIR74          float64
# CIR75          float64
# CIR76          float64
# CIR77          float64
# CIR78          float64
# CIR79          float64
# CIR80          float64
# CIR81          float64
# CIR82          float64
# CIR83          float64
# CIR84          float64
# CIR85          float64
# CIR86          float64
# CIR87          float64
# CIR88          float64
# CIR89          float64
# CIR90          float64
# CIR91          float64
# CIR92          float64
# CIR93          float64
# CIR94          float64
# CIR95          float64
# CIR96          float64
# CIR97          float64
# CIR98          float64
# CIR99          float64
# CIR100         float64
# CIR101         float64
# CIR102         float64
# CIR103         float64
# CIR104         float64
# CIR105         float64
# CIR106         float64
# CIR107         float64
# CIR108         float64
# CIR109         float64
# CIR110         float64
# CIR111         float64
# CIR112         float64
# CIR113         float64
# CIR114         float64
# CIR115         float64
# CIR116         float64
# CIR117         float64
# CIR118         float64
# CIR119         float64
# CIR120         float64
# CIR121         float64
# CIR122         float64
# CIR123         float64
# CIR124         float64
# CIR125         float64
# CIR126         float64
# CIR127         float64
# CIR128         float64
# CIR129         float64
# CIR130         float64
# CIR131         float64
# CIR132         float64
# CIR133         float64
# CIR134         float64
# CIR135         float64
# CIR136         float64
# CIR137         float64
# CIR138         float64
# CIR139         float64
# CIR140         float64
# CIR141         float64
# CIR142         float64
# CIR143         float64
# CIR144         float64
# CIR1007        float64
# CIR1008        float64
# CIR1009        float64
# CIR1010        float64
# CIR1011        float64
# CIR1012        float64
# CIR1013        float64
# CIR1014        float64
# CIR1015        float64
# Environment     object
# dtype: object

# %%
# 5. Check environment distribution
print("\n=== ENVIRONMENT DISTRIBUTION ===")
env_counts = combined_data_with_env['Environment'].value_counts()
print(env_counts)

env_balanced = True
for env, count in env_counts.items():
    if count != 6000:
        print(f"Environment '{env}' has {count} samples instead of expected 6,000")
        env_balanced = False

if env_balanced:
    print("All environments have the expected 6,000 samples")

plt.figure(figsize=(12, 6))
ax = sns.barplot(x=env_counts.index, y=env_counts.values, palette='viridis')
plt.title('Sample Distribution Across Environments', fontsize=14)
plt.xlabel('Environment', fontsize=12)
plt.ylabel('Number of Samples', fontsize=12)
plt.axhline(y=6000, color='r', linestyle='--', alpha=0.5, label='Expected count (6,000)')
plt.legend()
plt.grid(axis='y', alpha=0.3)

# Add count labels on bars
for i, count in enumerate(env_counts.values):
    color = 'green' if count == 6000 else 'red'
    plt.text(i, count + 100, f"{count:,}", ha='center', fontsize=10, color=color)

plt.tight_layout()
plt.show()
# Out:
# === ENVIRONMENT DISTRIBUTION ===
# Environment
# Office 1                      6000
# Office 2                      6000
# Small Apartment               6000
# Small Workshop                6000
# Kitchen with a living room    6000
# Bedroom                       6000
# Boiler room                   6000
# Name: count, dtype: int64
# All environments have the expected 6,000 samples
# C:\Users\Leong Jing Feng\AppData\Local\Temp\ipykernel_31936\4017042791.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=env_counts.index, y=env_counts.values, palette='viridis')

# %%
import seaborn as sns
import numpy as np
import pandas as pd

def compare_feature_means(df, selected_features, target_column='NLOS'):
    available_features = [f for f in selected_features if f in df.columns]
    
    results = []
    for feature in available_features:
        los_mean = df[df[target_column] == 0][feature].mean()
        nlos_mean = df[df[target_column] == 1][feature].mean()
        percent_diff = abs(los_mean - nlos_mean) / ((los_mean + nlos_mean) / 2) * 100 if (los_mean + nlos_mean) != 0 else 0
        
        results.append({'Feature': feature, 'LOS Mean': los_mean, 'NLOS Mean': nlos_mean, 'Percent Difference': percent_diff})
    
    results_df = pd.DataFrame(results).sort_values('Percent Difference', ascending=False)
    
    return results_df

# %%
# Compute feature comparison
selected_features = [
    'FP_IDX', 'FP_AMP1', 'FP_AMP2', 'FP_AMP3', 
    'CIR_PWR', 'RXPACC', 'FRAME_LEN', 'PREAM_LEN'
]

results_df = compare_feature_means(combined_data_with_env, selected_features)

print(results_df[['Feature', 'LOS Mean', 'NLOS Mean', 'Percent Difference']])

plt.figure(figsize=(12, 6))
x = np.arange(len(results_df))
width = 0.4

plt.bar(x - width/2, results_df['LOS Mean'].fillna(0), width, label='LOS', color='skyblue')
plt.bar(x + width/2, results_df['NLOS Mean'].fillna(0), width, label='NLOS', color='salmon')

plt.xticks(x, results_df['Feature'], rotation=45, ha='right')
plt.ylabel('Mean Value')
plt.title('LOS vs NLOS Feature Comparison')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#      Feature      LOS Mean    NLOS Mean  Percent Difference
# 5     RXPACC    392.110143   840.434857           72.747805
# 1    FP_AMP1  10539.815381  5715.228429           59.361107
# 2    FP_AMP2  14698.228810  8152.290238           57.293566
# 3    FP_AMP3  12490.976238  6985.235857           56.538103
# 4    CIR_PWR  11716.876810  7862.503619           39.371759
# 7  PREAM_LEN   1024.633905  1061.327238            3.518122
# 6  FRAME_LEN     33.597714    34.005810            1.207319
# 0     FP_IDX    747.082143   744.226190            0.383013

# %%
import pandas as pd
import matplotlib.pyplot as plt

cir_columns = [f'CIR{i}' for i in range(1016)]

print("Data types of CIR columns:")
print(combined_data_with_env[cir_columns].dtypes.unique())

print(f"Number of CIR columns: {len(cir_columns)}")

missing_values = combined_data_with_env[cir_columns].isnull().sum()
print("Missing values in CIR columns:")
print(missing_values[missing_values > 0]) 

sampled_cir = combined_data_with_env[cir_columns].sample(n=5, random_state=42)

for i, (index, row) in enumerate(sampled_cir.iterrows()):
    plt.figure(figsize=(10, 5))
    plt.plot(row.values, label=f"Row {index}", color='b')
    plt.title(f"Channel Impulse Response (CIR) - Row {index}")
    plt.xlabel("Time Sample")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.show()
# Out:
# Data types of CIR columns:
# [dtype('float64')]
# Number of CIR columns: 1016
# Missing values in CIR columns:
# Series([], dtype: int64)

# %% [markdown]
# #### **Data Cleaning [Part 1]**

# %% [markdown]
# #### **Check for null value**

# %%
# Find columns with missing values
missing_values = combined_data_with_env.isnull().sum()
missing_cols = missing_values[missing_values > 0]

print("Columns with missing values:")
if not missing_cols.empty:
    print(missing_cols)
    combined_data_with_env = combined_data_with_env.dropna()
    print("Rows with missing values have been removed.")
else:
    print("No missing values found.")
# Out:
# Columns with missing values:
# No missing values found.

# %% [markdown]
# #### **Check for duplicate value**

# %%
# Check for duplicate rows
duplicate_rows = combined_data_with_env.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")

if duplicate_rows > 0:
    combined_data_with_env = combined_data_with_env.drop_duplicates()
    print(f"{duplicate_rows} duplicate rows removed.")
else:
    print("No duplicate rows found.")
print(f"Final dataset shape: {combined_data_with_env.shape}")
# Out:
# Number of duplicate rows: 0
# No duplicate rows found.
# Final dataset shape: (42000, 1032)

# %% [markdown]
# ## Baseline DF = combined_data_with_env

# %% [markdown]
# #### **One-Hot Encoding Enviroment Feature**

# %%
env_encoded = pd.get_dummies(combined_data_with_env['Environment'], prefix='Env')
combined_data_with_encoding = pd.concat([combined_data_with_env, env_encoded], axis=1)

# %%
combined_data_with_encoding.head()
# Out:
#    NLOS  RANGE  FP_IDX  FP_AMP1  FP_AMP2  FP_AMP3  STDEV_NOISE  CIR_PWR  \
# 0   0.0   3.90   745.0  18712.0  10250.0  11576.0         64.0  11855.0
# 1   0.0   0.66   749.0  11239.0   6313.0   4712.0         64.0  18968.0
# 2   1.0   7.86   746.0   4355.0   5240.0   3478.0         60.0  14699.0
# 3   1.0   3.48   750.0   8502.0   8416.0   5890.0         76.0   8748.0
# 4   0.0   1.19   746.0  17845.0  18095.0  12058.0         68.0  11380.0
#
#    MAX_NOISE  RXPACC  ...  CIR1014  CIR1015  Environment  Env_Bedroom  \
# %% [markdown]
# #### **Data Feature Extraction**

# %% [markdown]
# #### **FP_AMP1,2,3**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from itertools import combinations

# Raw values
combined_data_with_encoding['FP_Mean'] = combined_data_with_encoding[['FP_AMP1', 'FP_AMP2', 'FP_AMP3']].mean(axis=1)
combined_data_with_encoding['FP_Range'] = combined_data_with_encoding[['FP_AMP1', 'FP_AMP2', 'FP_AMP3']].max(axis=1) - combined_data_with_encoding[['FP_AMP1', 'FP_AMP2', 'FP_AMP3']].min(axis=1)

# Avoid divide by zero errors for ratios
combined_data_with_encoding['FP_Ratio_12'] = combined_data_with_encoding['FP_AMP1'] / (combined_data_with_encoding['FP_AMP2'] + 1e-9)
combined_data_with_encoding['FP_Ratio_13'] = combined_data_with_encoding['FP_AMP1'] / (combined_data_with_encoding['FP_AMP3'] + 1e-9)
combined_data_with_encoding['FP_Ratio_23'] = combined_data_with_encoding['FP_AMP2'] / (combined_data_with_encoding['FP_AMP3'] + 1e-9)

# 2. Power-based feature
A = 121.74 
combined_data_with_encoding['FP_POWER'] = 10 * np.log10(
    (combined_data_with_encoding['FP_AMP1']**2 + combined_data_with_encoding['FP_AMP2']**2 + combined_data_with_encoding['FP_AMP3']**2) / (combined_data_with_encoding['RXPACC']**2)
) - A


feature_sets = {
    "Raw": ['FP_AMP1', 'FP_AMP2', 'FP_AMP3'],
    "Mean_Range": ['FP_Mean', 'FP_Range'],
    "Ratios": ['FP_Ratio_12', 'FP_Ratio_13', 'FP_Ratio_23'],
    "Power-based": ['FP_POWER']
}

all_combinations = {}
for r in range(1, len(feature_sets) + 1):
    for combo in combinations(feature_sets.keys(), r):
        combo_name = "+".join(combo)
        combo_features = []
        for feature_set in combo:
            combo_features.extend(feature_sets[feature_set])
        all_combinations[combo_name] = combo_features

all_combinations.update(feature_sets)

target = combined_data_with_encoding['NLOS']

# %%
results = {}

for name, features in all_combinations.items():
    X = combined_data_with_encoding[features]
    X_train, X_test, y_train, y_test = train_test_split(X, target, test_size=0.3, random_state=42)

    rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
    rf_classifier.fit(X_train, y_train)

    y_pred = rf_classifier.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[name] = accuracy

print("Model accuracy for different feature extraction methods and combinations:")
for method, acc in results.items():
    print(f"{method}: {acc:.4f}")
# Out:
# Model accuracy for different feature extraction methods and combinations:
# Raw: 0.7522
# Mean_Range: 0.7248
# Ratios: 0.5284
# Power-based: 0.7579
# Raw+Mean_Range: 0.7503
# Raw+Ratios: 0.7488
# Raw+Power-based: 0.8502
# Mean_Range+Ratios: 0.7512
# Mean_Range+Power-based: 0.8463
# Ratios+Power-based: 0.8305
# Raw+Mean_Range+Ratios: 0.7491
# Raw+Mean_Range+Power-based: 0.8476
# Raw+Ratios+Power-based: 0.8490
# Mean_Range+Ratios+Power-based: 0.8496
# Raw+Mean_Range+Ratios+Power-based: 0.8483

# %%
plt.figure(figsize=(12, 6))
plt.bar(results.keys(), results.values(), color='skyblue')
plt.title('Model Accuracy by Feature Extraction Method and Combinations')
plt.ylabel('Accuracy')
plt.xticks(rotation=90) 
plt.ylim(0, 1)  
plt.tight_layout() 
plt.show()

# %%
#keep only the FP-POWER
columns_to_remove = [
     'FP_Mean', 'FP_Range',
    'FP_Ratio_12', 'FP_Ratio_13', 'FP_Ratio_23'
]

combined_data_with_encoding = combined_data_with_encoding.drop(columns=columns_to_remove)

print(combined_data_with_encoding.head())
# Out:
#    NLOS  RANGE  FP_IDX  FP_AMP1  FP_AMP2  FP_AMP3  STDEV_NOISE  CIR_PWR  \
# 0   0.0   3.90   745.0  18712.0  10250.0  11576.0         64.0  11855.0
# 1   0.0   0.66   749.0  11239.0   6313.0   4712.0         64.0  18968.0
# 2   1.0   7.86   746.0   4355.0   5240.0   3478.0         60.0  14699.0
# 3   1.0   3.48   750.0   8502.0   8416.0   5890.0         76.0   8748.0
# 4   0.0   1.19   746.0  17845.0  18095.0  12058.0         68.0  11380.0
#
#    MAX_NOISE  RXPACC  ...  CIR1015  Environment  Env_Bedroom  Env_Boiler room  \
# 0      967.0   611.0  ...      0.0     Office 1        False            False
# 1     1133.0   447.0  ...      0.0     Office 1        False            False
# 2      894.0   723.0  ...      0.0     Office 1        False            False
# 3     1127.0  1024.0  ...    256.0     Office 1        False            False
# 4     1744.0   276.0  ...    256.0     Office 1        False            False
#
#    Env_Kitchen with a living room  Env_Office 1  Env_Office 2  \
# 0                           False          True         False
# 1                           False          True         False
# 2                           False          True         False
# 3                           False          True         False
# 4                           False          True         False
#
#    Env_Small Apartment  Env_Small Workshop    FP_POWER
# 0                False               False  -89.758158
# 1                False               False  -91.995986
# 2                False               False -101.249715
# 3                False               False  -99.446556
# 4                False               False  -81.574943
#
# [5 rows x 1040 columns]

# %% [markdown]
# #### **CIR_Values**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import PolynomialFeatures

# %%
#Check whether if CIR_value is linear or non-linear)
pca_data = combined_data_with_encoding.loc[:, 'CIR0':'CIR1015'].copy()  # Select columns CIR0 to CIR1015
target = combined_data_with_encoding['NLOS']  # Target variable (NLOS)

correlation_with_target = pca_data.corrwith(target)
print("Correlation with target (NLOS):")
print(correlation_with_target)
# Out:
# Correlation with target (NLOS):
# CIR0       0.204386
# CIR1       0.181933
# CIR2       0.133125
# CIR3       0.177418
# CIR4       0.099459
#              ...
# CIR1011    0.183408
# CIR1012    0.095495
# CIR1013    0.182948
# CIR1014    0.229277
# CIR1015    0.092241
# Length: 1016, dtype: float64

# %%
top_corr_features = correlation_with_target.abs().nlargest(10)
print("Top 10 features with highest correlation to NLOS:")
print(top_corr_features)
# Out:
# Top 10 features with highest correlation to NLOS:
# CIR751    0.331593
# CIR742    0.318422
# CIR741    0.317597
# CIR752    0.316465
# CIR750    0.300113
# CIR574    0.297642
# CIR582    0.279876
# CIR753    0.279043
# CIR326    0.278957
# CIR575    0.276699
# dtype: float64

# %%
top_feature_names = top_corr_features.index.tolist()

# %%
from sklearn.linear_model import LinearRegression

fig, axes = plt.subplots(5, 2, figsize=(15, 25))
axes = axes.flatten()

for i, feature in enumerate(top_feature_names):
    ax = axes[i]
    
    x = pca_data[feature].values.reshape(-1, 1)
    y = target.values
    
    ax.scatter(x, y, alpha=0.3, s=1)
    
    lr = LinearRegression()
    lr.fit(x, y)
    x_range = np.linspace(x.min(), x.max(), 100).reshape(-1, 1)
    ax.plot(x_range, lr.predict(x_range), 'r-', linewidth=2, label='Linear fit')
    
    poly = PolynomialFeatures(degree=3)
    x_poly = poly.fit_transform(x)
    x_range_poly = poly.transform(x_range)
    
    lr_poly = LinearRegression()
    lr_poly.fit(x_poly, y)
    y_poly = lr_poly.predict(x_range_poly)
    
    ax.plot(x_range, y_poly, 'g-', linewidth=2, label='Polynomial fit')
    

    y_pred_linear = lr.predict(x)
    r2_linear = np.corrcoef(y, y_pred_linear.flatten())[0, 1]**2
    
    y_pred_poly = lr_poly.predict(x_poly)
    r2_poly = np.corrcoef(y, y_pred_poly)[0, 1]**2
    
    r2_improvement = r2_poly - r2_linear
    
    ax.set_title(f'{feature} vs NLOS (r={correlation_with_target[feature]:.3f})\nR² Linear: {r2_linear:.3f}, R² Poly: {r2_poly:.3f}, Improvement: {r2_improvement:.3f}')
    ax.set_xlabel(feature)
    ax.set_ylabel('NLOS')
    ax.legend()
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
top_10_features = ["CIR751", "CIR742", "CIR741", "CIR752", "CIR750",
                   "CIR574", "CIR582", "CIR753", "CIR326", "CIR575"]
X_top10 = combined_data_with_encoding[top_10_features]
y = combined_data_with_encoding['NLOS']  # Target variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X_top10, y, test_size=0.3, stratify=y, random_state=42)

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)  

linear_model = LogisticRegression(max_iter=1000)
non_linear_model = MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=100)

# %%
# Train models on the training data
linear_model.fit(X_train_scaled, y_train)
non_linear_model.fit(X_train_scaled, y_train)

linear_train_pred = linear_model.predict(X_train_scaled)
non_linear_train_pred = non_linear_model.predict(X_train_scaled)

linear_train_acc = accuracy_score(y_train, linear_train_pred)
non_linear_train_acc = accuracy_score(y_train, non_linear_train_pred)

linear_test_pred = linear_model.predict(X_test_scaled)
non_linear_test_pred = non_linear_model.predict(X_test_scaled)

linear_test_acc = accuracy_score(y_test, linear_test_pred)
non_linear_test_acc = accuracy_score(y_test, non_linear_test_pred)

print("Training Data Results:")
print(f"Linear model accuracy (training): {linear_train_acc:.4f}")
print(f"Non-linear model accuracy (training): {non_linear_train_acc:.4f}")
print(f"Difference (non-linear - linear) (training): {non_linear_train_acc - linear_train_acc:.4f}")

print("\nTest Data Results:")
print(f"Linear model accuracy (test): {linear_test_acc:.4f}")
print(f"Non-linear model accuracy (test): {non_linear_test_acc:.4f}")
print(f"Difference (non-linear - linear) (test): {non_linear_test_acc - linear_test_acc:.4f}")

print("\nA large positive difference suggests non-linear relationships.")
# Out:
# Training Data Results:
# Linear model accuracy (training): 0.7586
# Non-linear model accuracy (training): 0.7999
# Difference (non-linear - linear) (training): 0.0413
#
# Test Data Results:
# Linear model accuracy (test): 0.7521
# Non-linear model accuracy (test): 0.7569
# Difference (non-linear - linear) (test): 0.0048
#
# A large positive difference suggests non-linear relationships.
# C:\Users\Leong Jing Feng\anaconda3\envs\DA_Project\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# #### **PCA dimensionality reduction**

# %%
mean_vals = pca_data.mean(axis=0)  
centered_data = pca_data - mean_vals

# %%
cov_matrix = np.cov(centered_data, rowvar=False)

# %%
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

# %%
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix) 

sorted_indices = np.argsort(eigenvalues)[::-1]  
eigenvalues = eigenvalues[sorted_indices]  
eigenvectors = eigenvectors[:, sorted_indices]

# %%
explained_variance_ratio = eigenvalues / np.sum(eigenvalues) 
cumulative_variance = np.cumsum(explained_variance_ratio)  

k = np.argmax(cumulative_variance >= 0.60) + 1  
top_k_eigenvectors = eigenvectors[:, :k]  

pca_transformed_data = np.dot(centered_data, top_k_eigenvectors)

# %%
pca_feature_names = [f"PC{i+1}" for i in range(k)] 

pca_df = pd.DataFrame(pca_transformed_data, columns=pca_feature_names)

# %%
print(f"Original Data Shape: {pca_data.shape}")
print(f"Reduced Data Shape: {pca_df.shape}")
print(f"Explained Variance by {k} PCs: {cumulative_variance[k-1]:.4f}")
# Out:
# Original Data Shape: (42000, 1016)
# Reduced Data Shape: (42000, 5)
# Explained Variance by 5 PCs: 0.6044

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='--', color='blue')
plt.axhline(y=0.60, color='red', linestyle='--', label='80% Explained Variance')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance by PCA')
plt.legend()
plt.grid(True)
plt.show()

# %%
print(pca_df.columns.tolist())
# Out:
# ['PC1', 'PC2', 'PC3', 'PC4', 'PC5']

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

X_pca = pca_df.copy()
y = combined_data_with_encoding['NLOS']

X_train_pca, X_test_pca, y_train, y_test = train_test_split(X_pca, y, test_size=0.3, random_state=42, stratify=y)

svm_pca = SVC()
svm_pca.fit(X_train_pca, y_train)

y_pred_svm_pca = svm_pca.predict(X_test_pca)

svm_pca_acc = accuracy_score(y_test, y_pred_svm_pca)
print(f"✅ PCA + SVM Accuracy: {svm_pca_acc:.4f} ({svm_pca_acc*100:.2f}%)\n")

rf_pca = RandomForestClassifier(n_estimators=100, random_state=42)
rf_pca.fit(X_train_pca, y_train)

y_pred_rf_pca = rf_pca.predict(X_test_pca)

rf_pca_acc = accuracy_score(y_test, y_pred_rf_pca)
print(f"✅ PCA + Random Forest Accuracy: {rf_pca_acc:.4f} ({rf_pca_acc*100:.2f}%)")
# Out:
# ✅ PCA + SVM Accuracy: 0.7844 (78.44%)
#
# ✅ PCA + Random Forest Accuracy: 0.7735 (77.35%)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

mean_vals = pca_data.mean(axis=0) 
centered_data = pca_data - mean_vals  

cov_matrix = np.cov(centered_data, rowvar=False) 


eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)  


sorted_indices = np.argsort(eigenvalues)[::-1]  
eigenvalues = eigenvalues[sorted_indices]  
eigenvectors = eigenvectors[:, sorted_indices]  


explained_variance_ratio = eigenvalues / np.sum(eigenvalues) 
cumulative_variance = np.cumsum(explained_variance_ratio)  


pca_datasets = {}  # Dictionary to store PCA-transformed data
results = []  # Store accuracy results


variance_levels = np.arange(0.95, 0.40, -0.10)  # 95% → 45% in steps of 10%

for variance_threshold in variance_levels:
    k = np.argmax(cumulative_variance >= variance_threshold) + 1
    top_k_eigenvectors = eigenvectors[:, :k]

    pca_transformed_data = np.dot(centered_data, top_k_eigenvectors)

    pca_datasets[f"PCA_{int(variance_threshold*100)}%"] = pd.DataFrame(
        pca_transformed_data, columns=[f"PC{i+1}" for i in range(k)]
    )

    X_train_pca, X_test_pca, y_train, y_test = train_test_split(
        pca_transformed_data, y, test_size=0.3, random_state=42, stratify=y
    )

    svm = SVC()
    svm.fit(X_train_pca, y_train)
    y_pred_svm = svm.predict(X_test_pca)
    svm_acc = accuracy_score(y_test, y_pred_svm)

    rf = RandomForestClassifier(n_estimators=100, random_state=42)
    rf.fit(X_train_pca, y_train)
    y_pred_rf = rf.predict(X_test_pca)
    rf_acc = accuracy_score(y_test, y_pred_rf)

    results.append({
        'Variance Retained': variance_threshold * 100,  # Convert to percentage
        'PCA Components': k,
        'SVM Accuracy': svm_acc * 100,
        'RF Accuracy': rf_acc * 100
    })

    print(f"✅ PCA Variance: {variance_threshold*100:.0f}% | Components: {k} | SVM Acc: {svm_acc:.4f} | RF Acc: {rf_acc:.4f}")

results_df = pd.DataFrame(results)

plt.figure(figsize=(10, 6))
plt.plot(results_df['Variance Retained'], results_df['SVM Accuracy'], marker='o', label='SVM Accuracy', color='blue')
plt.plot(results_df['Variance Retained'], results_df['RF Accuracy'], marker='s', label='Random Forest Accuracy', color='green')
plt.xlabel('Explained Variance (%)')
plt.ylabel('Accuracy (%)')
plt.title('Model Accuracy vs PCA Variance Retention (CIR Features Only)')
plt.legend()
plt.grid(True)
plt.show()

print("\n📊 **Final Results**:")
print(results_df)

print("\n✅ Stored PCA datasets (Choose one for final training):")
print(list(pca_datasets.keys()))
# Out:
# ✅ PCA Variance: 95% | Components: 39 | SVM Acc: 0.8260 | RF Acc: 0.8053
# ✅ PCA Variance: 85% | Components: 17 | SVM Acc: 0.8019 | RF Acc: 0.7887
# ✅ PCA Variance: 75% | Components: 10 | SVM Acc: 0.7912 | RF Acc: 0.7820
# ✅ PCA Variance: 65% | Components: 7 | SVM Acc: 0.7876 | RF Acc: 0.7783
# ✅ PCA Variance: 55% | Components: 4 | SVM Acc: 0.7817 | RF Acc: 0.7660
# ✅ PCA Variance: 45% | Components: 3 | SVM Acc: 0.7762 | RF Acc: 0.7621
# 📊 **Final Results**:
#    Variance Retained  PCA Components  SVM Accuracy  RF Accuracy
# 0               95.0              39     82.603175    80.531746
# 1               85.0              17     80.190476    78.865079
# 2               75.0              10     79.119048    78.198413
# 3               65.0               7     78.761905    77.833333
# 4               55.0               4     78.166667    76.595238
# 5               45.0               3     77.619048    76.206349
#
# ✅ Stored PCA datasets (Choose one for final training):
# ['PCA_95%', 'PCA_85%', 'PCA_75%', 'PCA_65%', 'PCA_55%', 'PCA_45%']

# %% [markdown]
# #### **Do manual feature extraction on CIR**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from scipy.stats import skew, kurtosis

def extract_cir_features(df):
    """
    Extract statistical features from CIR time series data (CIR0 to CIR1015)
    """
    features = pd.DataFrame(index=df.index)
    
    cir_data = df.values
    
    # Calculate statistical features
    features['cir_max'] = np.max(cir_data, axis=1)
    features['cir_min'] = np.min(cir_data, axis=1)
    features['cir_mean'] = np.mean(cir_data, axis=1)
    features['cir_std'] = np.std(cir_data, axis=1)
    features['cir_median'] = np.median(cir_data, axis=1)
    features['cir_energy'] = np.sum(cir_data**2, axis=1)
    features['cir_skewness'] = skew(cir_data, axis=1)
    features['cir_kurtosis'] = kurtosis(cir_data, axis=1)
    
    # Time-domain features
    features['cir_max_idx'] = np.argmax(cir_data, axis=1)  # Index of maximum value
    
    # First significant peak (values above mean + std)
    first_peaks = []
    for row in cir_data:
        threshold = np.mean(row) + np.std(row)
        peaks = np.where(row > threshold)[0]
        first_peak = peaks[0] if len(peaks) > 0 else -1
        first_peaks.append(first_peak)
    features['cir_first_peak_idx'] = first_peaks
    
    # Count of peaks above threshold
    peak_counts = []
    for row in cir_data:
        threshold = np.mean(row) + np.std(row)
        peaks = np.sum(row > threshold)
        peak_counts.append(peaks)
    features['cir_peak_count'] = peak_counts
    
    # Calculate percentiles
    features['cir_25_percentile'] = np.percentile(cir_data, 25, axis=1)
    features['cir_75_percentile'] = np.percentile(cir_data, 75, axis=1)
    features['cir_iqr'] = features['cir_75_percentile'] - features['cir_25_percentile']
    
    # Power-related features
    features['cir_power'] = np.sum(np.abs(cir_data), axis=1)
    features['cir_rms'] = np.sqrt(np.mean(cir_data**2, axis=1))
    
    # First and last non-zero values
    first_non_zero = []
    last_non_zero = []
    for row in cir_data:
        non_zeros = np.where(np.abs(row) > 0.01)[0]  # Adjust threshold as needed
        first = non_zeros[0] if len(non_zeros) > 0 else -1
        last = non_zeros[-1] if len(non_zeros) > 0 else -1
        first_non_zero.append(first)
        last_non_zero.append(last)
    
    features['cir_first_non_zero'] = first_non_zero
    features['cir_last_non_zero'] = last_non_zero
    features['cir_signal_length'] = features['cir_last_non_zero'] - features['cir_first_non_zero']
    
    # Add ratio features
    features['cir_max_mean_ratio'] = features['cir_max'] / (features['cir_mean'] + 1e-10)
    
    return features

# %%
print("Extracting features from pca_data...")
cir_features = extract_cir_features(pca_data)

print("\nExtracted CIR features:")
cir_features.head()
# Out:
# Extracting features from pca_data...
#
# Extracted CIR features:
#    cir_max  cir_min    cir_mean      cir_std  cir_median    cir_energy  \
# 0  23077.0      0.0  395.225394  1225.669636       221.0  1.685005e+09
# 1  18059.0      0.0  444.060039  1631.688252       210.5  2.905349e+09
# 2  16809.0      0.0  503.485236  1362.842157       231.5  2.144610e+09
# 3  15742.0     13.0  413.054134  1046.969988       256.0  1.287028e+09
# 4  19583.0      1.0  363.357283  1198.971453       228.0  1.594674e+09
#
#    cir_skewness  cir_kurtosis  cir_max_idx  cir_first_peak_idx  \
# 0     10.545582    144.958572          748                 744
# 1      8.510976     77.034432          757                 750
# 2      7.090688     58.383480          754                 747
# 3      9.471998    105.653200          756                 750
# 4     11.772332    151.456101          750                 745
#
#    cir_peak_count  cir_25_percentile  cir_75_percentile  cir_iqr  cir_power  \
# 0              25             158.75             286.25   127.50   401549.0
# 1              25             136.00             272.00   136.00   451165.0
# 2              44             159.00             310.25   151.25   511541.0
# 3              26             183.00             365.00   182.00   419663.0
# 4              16             151.75             291.00   139.25   369171.0
#
#        cir_rms  cir_first_non_zero  cir_last_non_zero  cir_signal_length  \
# 0  1287.815658                   0               1014               1014
# 1  1691.033965                   0               1014               1014
# 2  1452.871683                   0               1014               1014
# 3  1125.504275                   0               1015               1015
# 4  1252.821240                   0               1015               1015
#
#    cir_max_mean_ratio
# 0           58.389467
# 1           40.667924
# 2           33.385289
# 3           38.111227
# 4           53.894613

# %%
X = cir_features
y = combined_data_with_encoding['NLOS']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

print(f"\nTraining set size: {X_train.shape}")
print(f"Test set size: {X_test.shape}")
# Out:
# Training set size: (29400, 20)
# Test set size: (12600, 20)

# %%
svm_classifier = SVC()
svm_classifier.fit(X_train, y_train)

y_pred_svm = svm_classifier.predict(X_test)

svm_accuracy = accuracy_score(y_test, y_pred_svm)
print(f"SVM with extracted CIR features accuracy: {svm_accuracy:.4f} ({svm_accuracy*100:.2f}%)")

print("\nClassification Report (SVM):")
print(classification_report(y_test, y_pred_svm))
# Out:
# SVM with extracted CIR features accuracy: 0.6980 (69.80%)
#
# Classification Report (SVM):
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.92      0.75      6300
#          1.0       0.86      0.48      0.61      6300
#
#     accuracy                           0.70     12600
#    macro avg       0.75      0.70      0.68     12600
# weighted avg       0.75      0.70      0.68     12600

# %%
print("\nTraining Random Forest with extracted CIR features...")
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

y_pred_rf = rf_classifier.predict(X_test)

rf_accuracy = accuracy_score(y_test, y_pred_rf)
print(f"Random Forest with extracted CIR features accuracy: {rf_accuracy:.4f} ({rf_accuracy*100:.2f}%)")

print("\nClassification Report (Random Forest):")
print(classification_report(y_test, y_pred_rf))
# Out:
# Training Random Forest with extracted CIR features...
# Random Forest with extracted CIR features accuracy: 0.8277 (82.77%)
#
# Classification Report (Random Forest):
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.90      0.84      6300
#          1.0       0.89      0.75      0.81      6300
#
#     accuracy                           0.83     12600
#    macro avg       0.84      0.83      0.83     12600
# weighted avg       0.84      0.83      0.83     12600

# %%
print(f"Extracted CIR Features + SVM Accuracy: {svm_accuracy*100:.2f}%")
print(f"Extracted CIR Features + Random Forest Accuracy: {rf_accuracy*100:.2f}%")
# Out:
# Extracted CIR Features + SVM Accuracy: 69.80%
# Extracted CIR Features + Random Forest Accuracy: 82.77%

# %%
feature_importance = pd.DataFrame({
    'Feature': cir_features.columns,
    'Importance': rf_classifier.feature_importances_
})

feature_importance = feature_importance.sort_values('Importance', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x='Importance', y='Feature', data=feature_importance)
plt.title('CIR Feature Importance (Random Forest)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
cm_svm = confusion_matrix(y_test, y_pred_svm)
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('CIR Features + SVM')

plt.subplot(1, 2, 2)
cm_rf = confusion_matrix(y_test, y_pred_rf)
sns.heatmap(cm_rf, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('CIR Features + RF')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

cir_svm_acc = svm_accuracy * 100  
cir_rf_acc = rf_accuracy * 100  

pca_svm_acc = results_df['SVM Accuracy'].tolist()  
pca_rf_acc = results_df['RF Accuracy'].tolist() 
variance_levels = results_df['Variance Retained'].tolist()  

models = ['CIR Features + SVM', 'CIR Features + RF']

accuracies = [cir_svm_acc, cir_rf_acc]

for i, variance in enumerate(variance_levels):
    models.append(f'PCA {int(variance)}% + SVM')
    models.append(f'PCA {int(variance)}% + RF')
    accuracies.append(pca_svm_acc[i])
    accuracies.append(pca_rf_acc[i])

colors = ['blue', 'green'] + ['red', 'orange'] * len(variance_levels)

plt.figure(figsize=(12, 6))
bars = plt.bar(models, accuracies, color=colors)
plt.xlabel('Model')
plt.ylabel('Accuracy (%)')
plt.title('Comparison of Model Accuracies (PCA vs CIR Features)')
plt.ylim(60, 100)  
plt.xticks(rotation=45, ha='right')  

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.5,
             f'{height:.1f}%', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### **Combined with the other features**

# %%
# Select all columns that are not in the CIR0 to CIR1015 range
other_features = combined_data_with_encoding.drop(columns=pca_data.columns).copy()

# %%
pca_55_df = pca_datasets["PCA_55%"]  # Select the PCA 55% transformed data

# %%
final_combined_data = pd.concat([pca_55_df.reset_index(drop=True), 
                                 other_features.reset_index(drop=True)], axis=1)

# %%
print(final_combined_data.columns.tolist())
# Out:
# ['PC1', 'PC2', 'PC3', 'PC4', 'NLOS', 'RANGE', 'FP_IDX', 'FP_AMP1', 'FP_AMP2', 'FP_AMP3', 'STDEV_NOISE', 'CIR_PWR', 'MAX_NOISE', 'RXPACC', 'CH', 'FRAME_LEN', 'PREAM_LEN', 'BITRATE', 'PRFR', 'Environment', 'Env_Bedroom', 'Env_Boiler room', 'Env_Kitchen with a living room', 'Env_Office 1', 'Env_Office 2', 'Env_Small Apartment', 'Env_Small Workshop', 'FP_POWER']

# %% [markdown]
# #### **Feature Importance Ranking**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_features = final_combined_data.select_dtypes(include=['float64', 'int64'])

corr_matrix = numeric_features.corr()

plt.figure(figsize=(24, 20))

# Create the heatmap
sns.heatmap(
    corr_matrix,  
    annot=True,  
    fmt=".2f",    
    cmap="coolwarm",  
    vmin=-1,      
    vmax=1,       
    linewidths=0.5,  
    square=True   
)

plt.title("Correlation Heatmap of Numeric Features", fontsize=16)
plt.show()

# %%
#Feature Importance Ranking

# Drop the 'Environment' column (and any other non-numeric columns if present)
combined_data_with_FIR = final_combined_data.drop(columns=['Environment'])


X_nlos = combined_data_with_FIR.drop(columns=['NLOS', 'RANGE'])  # Keep only predictor features
y_nlos = combined_data_with_FIR['NLOS']

rf_nlos = RandomForestClassifier(n_estimators=100, random_state=42)
rf_nlos.fit(X_nlos, y_nlos)

feature_importance_nlos = pd.DataFrame({
    'Feature': X_nlos.columns,
    'Importance': rf_nlos.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("\n🔍 Feature Importance for Predicting NLOS:")
print(feature_importance_nlos)

plt.figure(figsize=(12, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_nlos[:10], palette='viridis')
plt.title('Top 10 Feature Importance for NLOS Prediction')
plt.show()
# Out:
# 🔍 Feature Importance for Predicting NLOS:
#                            Feature  Importance
# 24                        FP_POWER    0.224708
# 11                          RXPACC    0.213012
# 9                          CIR_PWR    0.079546
# 7                          FP_AMP3    0.078626
# 10                       MAX_NOISE    0.061968
# 6                          FP_AMP2    0.056508
# 5                          FP_AMP1    0.047625
# 1                              PC2    0.045748
# 2                              PC3    0.037814
# 8                      STDEV_NOISE    0.037163
# 0                              PC1    0.034756
# 3                              PC4    0.033126
# 4                           FP_IDX    0.021926
# 13                       FRAME_LEN    0.004933
# 23              Env_Small Workshop    0.003232
# 21                    Env_Office 2    0.003224
# 19  Env_Kitchen with a living room    0.003202
# 17                     Env_Bedroom    0.003136
# 20                    Env_Office 1    0.003130
# 18                 Env_Boiler room    0.003006
# 22             Env_Small Apartment    0.002953
# 14                       PREAM_LEN    0.000658
# 16                            PRFR    0.000000
# 12                              CH    0.000000
# 15                         BITRATE    0.000000
# C:\Users\Leong Jing Feng\AppData\Local\Temp\ipykernel_31936\1878213951.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_nlos[:10], palette='viridis')

# %%
#['FP_POWER', 'RXPACC', 'CIR_PWR', 'FP_AMP3', 'MAX_NOISE','FP_AMP2','FP_AMP1','PC2','PC3','STDEV_NOISE']

# %%
from sklearn.ensemble import RandomForestRegressor

los_data = combined_data_with_FIR[combined_data_with_FIR['NLOS'] == 0]
nlos_data = combined_data_with_FIR[combined_data_with_FIR['NLOS'] == 1]

X_los = los_data.drop(columns=['NLOS', 'RANGE'])
y_los = los_data['RANGE']

X_nlos = nlos_data.drop(columns=['NLOS', 'RANGE'])
y_nlos = nlos_data['RANGE']

rf_los = RandomForestRegressor(n_estimators=100, random_state=42)
rf_los.fit(X_los, y_los)

feature_importance_los = pd.DataFrame({
    'Feature': X_los.columns,
    'Importance': rf_los.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("\n🔍 Feature Importance for Predicting RANGE in LOS:")
print(feature_importance_los)

# Plot results
plt.figure(figsize=(12, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_los[:10], palette='coolwarm')
plt.title('Top 10 Feature Importance for LOS Range Prediction')
plt.show()

### 🔥 Train Random Forest for NLOS RANGE Prediction
rf_nlos_range = RandomForestRegressor(n_estimators=100, random_state=42)
rf_nlos_range.fit(X_nlos, y_nlos)

feature_importance_nlos_range = pd.DataFrame({
    'Feature': X_nlos.columns,
    'Importance': rf_nlos_range.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("\n🔍 Feature Importance for Predicting RANGE in NLOS:")
print(feature_importance_nlos_range)

# Plot results
plt.figure(figsize=(12, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_nlos_range[:10], palette='magma')
plt.title('Top 10 Feature Importance for NLOS Range Prediction')
plt.show()
# Out:
# 🔍 Feature Importance for Predicting RANGE in LOS:
#                            Feature  Importance
# 11                          RXPACC    0.457212
# 9                          CIR_PWR    0.160122
# 24                        FP_POWER    0.060731
# 10                       MAX_NOISE    0.046960
# 2                              PC3    0.039778
# 6                          FP_AMP2    0.036027
# 3                              PC4    0.031085
# 5                          FP_AMP1    0.029961
# 7                          FP_AMP3    0.029938
# 0                              PC1    0.026677
# 1                              PC2    0.026599
# 8                      STDEV_NOISE    0.025153
# 4                           FP_IDX    0.007270
# 13                       FRAME_LEN    0.003674
# 23              Env_Small Workshop    0.002761
# 18                 Env_Boiler room    0.002712
# 19  Env_Kitchen with a living room    0.002691
# 20                    Env_Office 1    0.002672
# 17                     Env_Bedroom    0.002650
# 22             Env_Small Apartment    0.002530
# 21                    Env_Office 2    0.002363
# 14                       PREAM_LEN    0.000434
# 16                            PRFR    0.000000
# 12                              CH    0.000000
# 15                         BITRATE    0.000000
# C:\Users\Leong Jing Feng\AppData\Local\Temp\ipykernel_31936\344438429.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_los[:10], palette='coolwarm')
# 🔍 Feature Importance for Predicting RANGE in NLOS:
#                            Feature  Importance
# 24                        FP_POWER    0.199547
# 11                          RXPACC    0.131187
# 9                          CIR_PWR    0.088493
# 14                       PREAM_LEN    0.088221
# 2                              PC3    0.082651
# 0                              PC1    0.059750
# 3                              PC4    0.054824
# 10                       MAX_NOISE    0.054280
# 1                              PC2    0.044998
# 5                          FP_AMP1    0.040106
# 7                          FP_AMP3    0.037498
# 6                          FP_AMP2    0.036033
# 4                           FP_IDX    0.030543
# 8                      STDEV_NOISE    0.017602
# 13                       FRAME_LEN    0.010439
# 18                 Env_Boiler room    0.003709
# 17                     Env_Bedroom    0.003664
# 19  Env_Kitchen with a living room    0.003466
# 21                    Env_Office 2    0.003356
# 22             Env_Small Apartment    0.003261
# 23              Env_Small Workshop    0.003240
# 20                    Env_Office 1    0.003132
# 16                            PRFR    0.000000
# 12                              CH    0.000000
# 15                         BITRATE    0.000000
# C:\Users\Leong Jing Feng\AppData\Local\Temp\ipykernel_31936\344438429.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Importance', y='Feature', data=feature_importance_nlos_range[:10], palette='magma')

# %%
#LOS
#['RXPACC', 'CIR_PWR', 'FP_POWER', 'MAX_NOISE', 'PC3', 'FP_AMP2','PC4','FP_AMP1','FP_AMP3','PC1']

#NLOS
#['FP_POWER', 'RXPACC', 'CIR_PWR', 'PREAM_LEN', 'PC3','PC1','PC4','MAX_NOISE','PC2','FP_AMP1']

# %%
# Define a threshold for low importance (< 0.01)
importance_threshold = 0.01  

# Find low-importance features in NLOS classification
low_importance_nlos = feature_importance_nlos[feature_importance_nlos['Importance'] < importance_threshold]['Feature'].tolist()

# Find low-importance features in LOS Range Prediction
low_importance_los = feature_importance_los[feature_importance_los['Importance'] < importance_threshold]['Feature'].tolist()

# Find low-importance features in NLOS Range Prediction
low_importance_nlos_range = feature_importance_nlos_range[feature_importance_nlos_range['Importance'] < importance_threshold]['Feature'].tolist()

# Find common features that are insignificant in all three models
common_low_importance_features = set(low_importance_nlos) & set(low_importance_los) & set(low_importance_nlos_range)

# Display common features to remove
print("\n🚨 Common Insignificant Features (To Remove):")
print(list(common_low_importance_features))
# Out:
# 🚨 Common Insignificant Features (To Remove):
# ['Env_Office 2', 'CH', 'Env_Small Workshop', 'Env_Boiler room', 'Env_Small Apartment', 'BITRATE', 'PRFR', 'Env_Kitchen with a living room', 'Env_Office 1', 'Env_Bedroom']

# %%
# Merge feature importance scores from all models
feature_importance_all = pd.DataFrame({
    'Feature': feature_importance_nlos['Feature']
}).merge(feature_importance_nlos, on='Feature', how='left', suffixes=('', '_NLOS')) \
  .merge(feature_importance_los, on='Feature', how='left', suffixes=('', '_LOS')) \
  .merge(feature_importance_nlos_range, on='Feature', how='left', suffixes=('', '_NLOS_Range'))

# Fill NaN values (if any feature was missing in one of the models)
feature_importance_all = feature_importance_all.fillna(0)

# Compute the average importance score across all models
feature_importance_all['Avg_Importance'] = feature_importance_all[['Importance', 'Importance_LOS', 'Importance_NLOS_Range']].mean(axis=1)

# Sort by average importance
feature_importance_all = feature_importance_all.sort_values(by='Avg_Importance', ascending=False)

# Select the top 5 most important features
top_5_features = feature_importance_all['Feature'].head(5).tolist()

# Display results
print("\n🔥 Top 5 Most Important Features Across All Models:")
print(top_5_features)
# Out:
# 🔥 Top 5 Most Important Features Across All Models:
# ['RXPACC', 'FP_POWER', 'CIR_PWR', 'MAX_NOISE', 'PC3']

# %% [markdown]
# #### **Data Cleaning [Part 2]**

# %%
# find columns with only 1 unique value
unique_counts = final_combined_data.nunique()
single_value_cols = unique_counts[unique_counts == 1]
print("Columns with only one unique value:")
if not single_value_cols.empty:
    print(single_value_cols)
else:
    print("No columns with a single unique value.")
# Out:
# Columns with only one unique value:
# CH         1
# BITRATE    1
# PRFR       1
# dtype: int64

# %%
# Select only numeric columns
numeric_data = final_combined_data.select_dtypes(include=['number'])

variance_threshold = 0.01 
low_variance_columns = numeric_data.columns[numeric_data.var() < variance_threshold]

print("Features with low variance (numeric only):")
print(low_variance_columns)
# Out:
# Features with low variance (numeric only):
# Index(['CH', 'BITRATE', 'PRFR'], dtype='object')

# %%
import numpy as np
import pandas as pd


X = final_combined_data.drop(columns=['NLOS'])  

nan_columns = X.columns[X.isna().any()].tolist()  
print("Columns with NaN values:")
print(nan_columns)

# Columns with positive infinity
inf_columns = X.columns[(X == np.inf).any()].tolist()  
# Columns with negative infinity
neg_inf_columns = X.columns[(X == -np.inf).any()].tolist() 
print("\nColumns with positive infinity values:")
print(inf_columns)

print("\nColumns with negative infinity values:")
print(neg_inf_columns)

all_problem_columns = set(nan_columns + inf_columns + neg_inf_columns)
print("\nAll columns with NaN or infinite values:")
print(all_problem_columns)
# Out:
# Columns with NaN values:
# []
#
# Columns with positive infinity values:
# []
#
# Columns with negative infinity values:
# []
#
# All columns with NaN or infinite values:
# set()

# %%
# List of columns to drop
columns_to_drop = ['CH', 'BITRATE', 'PRFR']

# Drop the columns
final_combined_data = final_combined_data.drop(columns=columns_to_drop)
print(f"Remaining columns after dropping: {final_combined_data.columns.tolist()}")
# Out:
# Remaining columns after dropping: ['PC1', 'PC2', 'PC3', 'PC4', 'NLOS', 'RANGE', 'FP_IDX', 'FP_AMP1', 'FP_AMP2', 'FP_AMP3', 'STDEV_NOISE', 'CIR_PWR', 'MAX_NOISE', 'RXPACC', 'FRAME_LEN', 'PREAM_LEN', 'Environment', 'Env_Bedroom', 'Env_Boiler room', 'Env_Kitchen with a living room', 'Env_Office 1', 'Env_Office 2', 'Env_Small Apartment', 'Env_Small Workshop', 'FP_POWER']

# %% [markdown]
# #### **Drop One-Hot Encoding Enviroment (Insignificant)**

# %%
columns_to_drop = ['Env_Bedroom', 'Env_Small Workshop', 'Env_Small Apartment', 'Env_Boiler room',
                   'Env_Office 1', 'Env_Office 2', 'Env_Kitchen with a living room']

# Drop the columns
final_combined_data = final_combined_data.drop(columns=columns_to_drop)
print(f"Remaining columns after dropping: {final_combined_data.columns.tolist()}")
# Out:
# Remaining columns after dropping: ['PC1', 'PC2', 'PC3', 'PC4', 'NLOS', 'RANGE', 'FP_IDX', 'FP_AMP1', 'FP_AMP2', 'FP_AMP3', 'STDEV_NOISE', 'CIR_PWR', 'MAX_NOISE', 'RXPACC', 'FRAME_LEN', 'PREAM_LEN', 'Environment', 'FP_POWER']

# %% [markdown]
# #### **Outliers**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


numeric_columns = final_combined_data.select_dtypes(include=['float64', 'int64']).columns
outlier_counts = pd.DataFrame(columns=['Feature', 'Outlier Count'])

plt.figure(figsize=(12, len(numeric_columns) * 3))

for i, col in enumerate(numeric_columns):
    Q1 = final_combined_data[col].quantile(0.25)
    Q3 = final_combined_data[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify outliers
    outliers = final_combined_data[(final_combined_data[col] < lower_bound) | (final_combined_data[col] > upper_bound)]
    outlier_counts.loc[i] = [col, len(outliers)]
    
    plt.subplot(len(numeric_columns), 1, i + 1)
    sns.boxplot(y=final_combined_data[col], color='skyblue')
    plt.title(f'{col} (Outliers: {len(outliers)})')
    plt.axhline(lower_bound, color='red', linestyle='--', label='Lower Bound')
    plt.axhline(upper_bound, color='red', linestyle='--', label='Upper Bound')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
print("Outlier counts for each numeric feature:")
print(outlier_counts)
# Out:
# Outlier counts for each numeric feature:
#         Feature  Outlier Count
# 0           PC1              0
# 1           PC2             13
# 2           PC3            353
# 3           PC4             82
# 4          NLOS              0
# 5         RANGE            121
# 6        FP_IDX           1757
# 7       FP_AMP1              0
# 8       FP_AMP2              0
# 9       FP_AMP3              0
# 10  STDEV_NOISE           1915
# 11      CIR_PWR            938
# 12    MAX_NOISE           2965
# 13       RXPACC              0
# 14    FRAME_LEN              0
# 15    PREAM_LEN           1557
# 16     FP_POWER              0

# %% [markdown]
# #### **Dropping outliers in the top 5 features only**

# %%
#['RXPACC', 'FP_POWER', 'CIR_PWR', 'MAX_NOISE', 'PC3']

# %%
# Top 5 most important features
top_features = ['RXPACC', 'FP_POWER', 'CIR_PWR', 'MAX_NOISE', 'PC3']
Q1 = final_combined_data[top_features].quantile(0.25)
Q3 = final_combined_data[top_features].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify rows with outliers in top features
outlier_mask_top = (final_combined_data[top_features] < lower_bound) | (final_combined_data[top_features] > upper_bound)
rows_with_top_outliers = outlier_mask_top.any(axis=1)
print(f"Number of rows with outliers in top features: {rows_with_top_outliers.sum()}")
# Out:
# Number of rows with outliers in top features: 4066

# %%
# Drop rows with outliers in top features
cleaned_data_top = final_combined_data[~rows_with_top_outliers]
print(f"Shape of cleaned data (top features): {cleaned_data_top.shape}")
# Out:
# Shape of cleaned data (top features): (37934, 18)

# %% [markdown]
# #### **Dropping all outliers**

# %%
import pandas as pd


data_without_targets = final_combined_data.drop(columns=['RANGE', 'NLOS'])
numeric_columns = data_without_targets.select_dtypes(include=['float32','float64', 'int64']).columns

Q1 = data_without_targets[numeric_columns].quantile(0.25)
Q3 = data_without_targets[numeric_columns].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify rows with outliers in any feature
outlier_mask_all = (data_without_targets[numeric_columns] < lower_bound) | (data_without_targets[numeric_columns] > upper_bound)
rows_with_all_outliers = outlier_mask_all.any(axis=1)


print(f"Number of rows with outliers in any feature: {rows_with_all_outliers.sum()}")
cleaned_data_all = final_combined_data[~rows_with_all_outliers]
print(f"Shape of cleaned data (all features): {cleaned_data_all.shape}")
# Out:
# Number of rows with outliers in any feature: 7306
# Shape of cleaned data (all features): (34694, 18)

# %% [markdown]
# #### **Comparing Accuracy only**

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

numeric_columns = cleaned_data_all.select_dtypes(include=['float32','float64', 'int64']).columns
numeric_columns = numeric_columns.drop(['NLOS', 'RANGE'])  


X_train_all, X_test_all, y_train_all, y_test_all = train_test_split(
    cleaned_data_all[numeric_columns],  
    cleaned_data_all['NLOS'],          
    test_size=0.3,
    random_state=42
)

# Train a Random Forest model
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train_all, y_train_all)

# Evaluate accuracy
y_pred_all = rf_classifier.predict(X_test_all)
accuracy_all = accuracy_score(y_test_all, y_pred_all)
print(f"Accuracy (all outliers, 'NLOS' dropped): {accuracy_all:.4f}")
# Out:
# Accuracy (all outliers, 'NLOS' dropped): 0.8567

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

numeric_columns = cleaned_data_top.select_dtypes(include=['float32','float64', 'int64']).columns
numeric_columns = numeric_columns.drop(['NLOS', 'RANGE'])  

X_train_all, X_test_all, y_train_all, y_test_all = train_test_split(
    cleaned_data_top[numeric_columns],  
    cleaned_data_top['NLOS'],          
    test_size=0.3,
    random_state=42
)

# Train a Random Forest model
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train_all, y_train_all)

# Evaluate accuracy
y_pred_all = rf_classifier.predict(X_test_all)
accuracy_all = accuracy_score(y_test_all, y_pred_all)
print(f"Accuracy (top features outlier removed, 'NLOS' dropped): {accuracy_all:.4f}")
# Out:
# Accuracy (top features outlier removed, 'NLOS' dropped): 0.8667

# %%
#Accuracy (all outliers, 'NLOS' dropped): 0.8567
#Accuracy (top features outlier removed, 'NLOS' dropped): 0.8667

# %% [markdown]
# #### **Classifier Model**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

X = cleaned_data_top[['FP_POWER', 'RXPACC', 'CIR_PWR', 'FP_AMP3', 'MAX_NOISE','FP_AMP2','FP_AMP1','PC2','PC3','STDEV_NOISE']] 
y = cleaned_data_top['NLOS']

# Train-test split (70-30) stratified by 'Environment'
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=cleaned_data_top['Environment'], random_state=42
)


print("Training set size:", X_train.shape)
print("Test set size:", X_test.shape)
# Out:
# Training set size: (26553, 10)
# Test set size: (11381, 10)

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Check for overfitting
def check_overfitting(model, X_train, y_train, X_test, y_test):
    train_acc = accuracy_score(y_train, model.predict(X_train))
    test_acc = accuracy_score(y_test, model.predict(X_test))
    print(f"Training Accuracy: {train_acc:.4f}")
    print(f"Test Accuracy: {test_acc:.4f}")
    print(f"Overfitting detected: {train_acc > test_acc + 0.1}")

# Calculate accuracy per environment
def env_accuracy(model, X_test, y_test):
    env_data = cleaned_data_top.loc[X_test.index, 'Environment']
    results = pd.DataFrame({'Environment': env_data, 'NLOS': y_test, 'Predictions': model.predict(X_test)})
    env_acc = results.groupby('Environment').apply(
        lambda group: accuracy_score(group['NLOS'], group['Predictions']), 
        include_groups=False
    )
    print("\nAccuracy by Environment:")
    print(env_acc)
    return env_acc

# Hyperparameter tuning + retraining with best model
def tune_and_retrain(model, param_grid, X_train, y_train, X_test, y_test):
    random_search = RandomizedSearchCV(
    model, param_grid, n_iter=10, cv=3, scoring='accuracy', random_state=42, n_jobs=-1
    )
    random_search.fit(X_train, y_train)
    
    best_model = random_search.best_estimator_  
    print("Best Hyperparameters:", random_search.best_params_)
    print("Best Cross-validation Score:", random_search.best_score_)
    
    best_model.fit(X_train, y_train)
    test_acc = accuracy_score(y_test, best_model.predict(X_test))
    print(f"Test Accuracy after tuning: {test_acc:.4f}")
    
    return best_model

# %%
import time

# %% [markdown]
# #### **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

start_time = time.time() 
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

print("\nDecision Tree Results:")
check_overfitting(dt_model, X_train, y_train, X_test, y_test)
env_accuracy(dt_model, X_test, y_test)

# Hyperparameter tuning and retraining
dt_params = {
    'max_depth': [None, 5, 10, 15, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}
dt_best = tune_and_retrain(dt_model, dt_params, X_train, y_train, X_test, y_test)
dt_time = time.time() - start_time
# Out:
# Decision Tree Results:
# Training Accuracy: 1.0000
# Test Accuracy: 0.7965
# Overfitting detected: True
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.783550
# Boiler room                   0.802826
# Kitchen with a living room    0.793884
# Office 1                      0.803934
# Office 2                      0.791975
# Small Apartment               0.799020
# Small Workshop                0.800247
# dtype: float64
# Best Hyperparameters: {'min_samples_split': 5, 'min_samples_leaf': 1, 'max_depth': 5, 'criterion': 'gini'}
# Best Cross-validation Score: 0.8534628855496554
# Test Accuracy after tuning: 0.8548

# %% [markdown]
# #### **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier


start_time = time.time()
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)

print("\nKNN Results:")
check_overfitting(knn_model, X_train, y_train, X_test, y_test)
env_accuracy(knn_model, X_test, y_test)

# Hyperparameter tuning and retraining
knn_params = {
    'n_neighbors': [3, 5, 7, 9, 11, 15],
    'weights': ['uniform', 'distance'],
    'p': [1, 2],  
    'leaf_size': [10, 30, 50]
}
knn_best = tune_and_retrain(knn_model, knn_params, X_train, y_train, X_test, y_test)
knn_time = time.time() - start_time
# Out:
# KNN Results:
# Training Accuracy: 0.8394
# Test Accuracy: 0.7715
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.765615
# Boiler room                   0.787469
# Kitchen with a living room    0.782263
# Office 1                      0.764597
# Office 2                      0.772222
# Small Apartment               0.763480
# Small Workshop                0.765105
# dtype: float64
# Best Hyperparameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 9, 'leaf_size': 10}
# Best Cross-validation Score: 0.7992317252287876
# Test Accuracy after tuning: 0.8029

# %% [markdown]
# #### **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression


start_time = time.time()
log_model = LogisticRegression(max_iter=5000)
log_model.fit(X_train, y_train)

print("\nLogistic Regression Results:")
check_overfitting(log_model, X_train, y_train, X_test, y_test)
env_accuracy(log_model, X_test, y_test)

# Hyperparameter tuning and retraining
log_params = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l2', 'l1', None],
    'solver': ['liblinear', 'saga', 'lbfgs'],
    'class_weight': [None, 'balanced']
}
log_best = tune_and_retrain(log_model, log_params, X_train, y_train, X_test, y_test)
lr_time = time.time() - start_time
# Out:
# Logistic Regression Results:
# Training Accuracy: 0.8473
# Test Accuracy: 0.8491
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.841064
# Boiler room                   0.855651
# Kitchen with a living room    0.858104
# Office 1                      0.851260
# Office 2                      0.830247
# Small Apartment               0.864583
# Small Workshop                0.842787
# dtype: float64
# Best Hyperparameters: {'solver': 'liblinear', 'penalty': 'l1', 'class_weight': None, 'C': 1}
# Best Cross-validation Score: 0.8499981169736
# Test Accuracy after tuning: 0.8522

# %% [markdown]
# #### **Neural Network (MLP Classifier)**

# %%
from sklearn.neural_network import MLPClassifier


start_time = time.time()
nn_model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, random_state=42)
nn_model.fit(X_train, y_train)

print("\nNeural Network Results:")
check_overfitting(nn_model, X_train, y_train, X_test, y_test)
env_accuracy(nn_model, X_test, y_test)

# Hyperparameter tuning and retraining
nn_params = {
    'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50)],
    'activation': ['relu', 'tanh'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'adaptive'],
    'max_iter': [200, 500]
}
nn_best = tune_and_retrain(nn_model, nn_params, X_train, y_train, X_test, y_test)
nn_time = time.time() - start_time
# Out:
# Neural Network Results:
# Training Accuracy: 0.8256
# Test Accuracy: 0.8197
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.816327
# Boiler room                   0.808354
# Kitchen with a living room    0.834862
# Office 1                      0.804548
# Office 2                      0.822840
# Small Apartment               0.819240
# Small Workshop                0.831689
# dtype: float64
# Best Hyperparameters: {'max_iter': 500, 'learning_rate': 'constant', 'hidden_layer_sizes': (50,), 'alpha': 0.01, 'activation': 'relu'}
# Best Cross-validation Score: 0.8141829548450269
# Test Accuracy after tuning: 0.8065

# %% [markdown]
# #### **Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC


start_time = time.time()
svm_model = SVC(kernel='rbf', random_state=42)
svm_model.fit(X_train, y_train)

print("\nSVM Results:")
check_overfitting(svm_model, X_train, y_train, X_test, y_test)
env_accuracy(svm_model, X_test, y_test)

# Hyperparameter tuning and retraining
svm_params = {
    'C': [0.1, 1, 10, 100],  # Narrow the range slightly
    'gamma': ['scale', 'auto', 0.01, 0.1],  # Fewer gamma values
    'class_weight': [None, 'balanced']
}
svm_best = tune_and_retrain(svm_model, svm_params, X_train, y_train, X_test, y_test)
svm_time = time.time() - start_time
# Out:
# SVM Results:
# Training Accuracy: 0.8395
# Test Accuracy: 0.8364
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.830550
# Boiler room                   0.834152
# Kitchen with a living room    0.847095
# Office 1                      0.833436
# Office 2                      0.831481
# Small Apartment               0.840074
# Small Workshop                0.837855
# dtype: float64
# Best Hyperparameters: {'gamma': 'scale', 'class_weight': None, 'C': 100}
# Best Cross-validation Score: 0.8562874251497007
# Test Accuracy after tuning: 0.8584

# %% [markdown]
# #### **Comparing Model Performance**

# %%
models = {
    "Decision Tree": dt_best,
    "KNN": knn_best,
    "Logistic Regression": log_best,
    "Neural Network": nn_best,
    "SVM": svm_best
}

results = {}
for name, model in models.items():
    acc = accuracy_score(y_test, model.predict(X_test))
    results[name] = acc

# Display test accuracies
results_df = pd.DataFrame.from_dict(results, orient='index', columns=['Test Accuracy'])
print("\nModel Comparison (After Hyperparameter Tuning):")
print(results_df)


results_df.sort_values(by='Test Accuracy', ascending=False).plot(kind='bar', color='skyblue', figsize=(10, 6))
plt.title('Model Comparison: Test Accuracies (After Tuning)')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Model Comparison (After Hyperparameter Tuning):
#                      Test Accuracy
# Decision Tree             0.854846
# KNN                       0.802917
# Logistic Regression       0.852210
# Neural Network            0.806520
# SVM                       0.858448

# %% [markdown]
# #### **Comparing Model Performance(Confusion Matrics)**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Function to plot confusion matrix
def plot_confusion_matrix(model, X_test, y_test, model_name):
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['LOS', 'NLOS'], yticklabels=['LOS', 'NLOS'])
    plt.title(f'Confusion Matrix - {model_name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    return cm

# %%
print("\nDecision Tree Results:")
check_overfitting(dt_best, X_train, y_train, X_test, y_test)
env_accuracy(dt_best, X_test, y_test)

# Plot confusion matrix
dt_cm = plot_confusion_matrix(dt_best, X_test, y_test, "Decision Tree")

print("\nKNN Results:")
check_overfitting(knn_best, X_train, y_train, X_test, y_test)
env_accuracy(knn_best, X_test, y_test)

# Plot confusion matrix
knn_cm = plot_confusion_matrix(knn_best, X_test, y_test, "KNN")

print("\nLogistic Regression Results:")
check_overfitting(log_best, X_train, y_train, X_test, y_test)
env_accuracy(log_best, X_test, y_test)

# Plot confusion matrix
log_cm = plot_confusion_matrix(log_best, X_test, y_test, "Logistic Regression")

print("\nLogistic Regression Results:")
check_overfitting(log_best, X_train, y_train, X_test, y_test)
env_accuracy(log_best, X_test, y_test)

# Plot confusion matrix
log_cm = plot_confusion_matrix(log_best, X_test, y_test, "Logistic Regression")

print("\nNeural Network Results:")
check_overfitting(nn_best, X_train, y_train, X_test, y_test)
env_accuracy(nn_best, X_test, y_test)

# Plot confusion matrix
nn_cm = plot_confusion_matrix(nn_best, X_test, y_test, "Neural Network")

print("\nSVM Results:")
check_overfitting(svm_best, X_train, y_train, X_test, y_test)
env_accuracy(svm_best, X_test, y_test)

# Plot confusion matrix
svm_cm = plot_confusion_matrix(svm_best, X_test, y_test, "SVM")
# Out:
# Decision Tree Results:
# Training Accuracy: 0.8592
# Test Accuracy: 0.8548
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.855906
# Boiler room                   0.861794
# Kitchen with a living room    0.855657
# Office 1                      0.850031
# Office 2                      0.845679
# Small Apartment               0.861520
# Small Workshop                0.853268
# dtype: float64
# KNN Results:
# Training Accuracy: 0.8354
# Test Accuracy: 0.8029
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.794063
# Boiler room                   0.815111
# Kitchen with a living room    0.816514
# Office 1                      0.794100
# Office 2                      0.798148
# Small Apartment               0.802083
# Small Workshop                0.800247
# dtype: float64
# Logistic Regression Results:
# Training Accuracy: 0.8508
# Test Accuracy: 0.8522
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.842301
# Boiler room                   0.863022
# Kitchen with a living room    0.859939
# Office 1                      0.850031
# Office 2                      0.833951
# Small Apartment               0.871324
# Small Workshop                0.844636
# dtype: float64
# Logistic Regression Results:
# Training Accuracy: 0.8508
# Test Accuracy: 0.8522
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.842301
# Boiler room                   0.863022
# Kitchen with a living room    0.859939
# Office 1                      0.850031
# Office 2                      0.833951
# Small Apartment               0.871324
# Small Workshop                0.844636
# dtype: float64
# Neural Network Results:
# Training Accuracy: 0.8096
# Test Accuracy: 0.8065
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.805195
# Boiler room                   0.817568
# Kitchen with a living room    0.813456
# Office 1                      0.804548
# Office 2                      0.792593
# Small Apartment               0.805147
# Small Workshop                0.807028
# dtype: float64
# SVM Results:
# Training Accuracy: 0.8614
# Test Accuracy: 0.8584
# Overfitting detected: False
#
# Accuracy by Environment:
# Environment
# Bedroom                       0.853432
# Boiler room                   0.869165
# Kitchen with a living room    0.865443
# Office 1                      0.850031
# Office 2                      0.848765
# Small Apartment               0.861520
# Small Workshop                0.860666
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(2, 3, figsize=(18, 12))  # Creates 6 subplots (2 rows, 3 columns)
fig.suptitle('Confusion Matrices for All Models', fontsize=20)

# List of models and their confusion matrices
models = [("Decision Tree", dt_cm), ("KNN", knn_cm), ("Logistic Regression", log_cm),
          ("Neural Network", nn_cm), ("SVM", svm_cm)]

for ax, (name, cm) in zip(axes.flatten()[:len(models)], models):
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['LOS', 'NLOS'], yticklabels=['LOS', 'NLOS'], ax=ax)
    ax.set_title(name)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('Actual')

if len(models) < 6:
    fig.delaxes(axes.flatten()[len(models)])

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Function to calculate and display similarity metrics
def calculate_similarity_metrics(model, X_test, y_test, model_name):
    y_pred = model.predict(X_test)
    precision = precision_score(y_test, y_pred, average='weighted')
    recall = recall_score(y_test, y_pred, average='weighted')
    f1 = f1_score(y_test, y_pred, average='weighted')
    
    print(f"\n{model_name} Similarity Metrics:")
    print(f"Precision: {precision:.3f}")
    print(f"Recall: {recall:.3f}")
    print(f"F1-Score: {f1:.3f}")
    print("\nDetailed Classification Report:")
    print(classification_report(y_test, y_pred))
    return precision, recall, f1


print("\nDecision Tree Similarity Metrics:")
dt_precision, dt_recall, dt_f1 = calculate_similarity_metrics(dt_best, X_test, y_test, "Decision Tree")

print("\nKNN Similarity Metrics:")
knn_precision, knn_recall, knn_f1 = calculate_similarity_metrics(knn_best, X_test, y_test, "KNN")

print("\nLogistic Regression Similarity Metrics:")
log_precision, log_recall, log_f1 = calculate_similarity_metrics(log_best, X_test, y_test, "Logistic Regression")

print("\nNeural Network Similarity Metrics:")
nn_precision, nn_recall, nn_f1 = calculate_similarity_metrics(nn_best, X_test, y_test, "Neural Network")

print("\nSVM Similarity Metrics:")
svm_precision, svm_recall, svm_f1 = calculate_similarity_metrics(svm_best, X_test, y_test, "SVM")
# Out:
# Decision Tree Similarity Metrics:
#
# Decision Tree Similarity Metrics:
# Precision: 0.860
# Recall: 0.855
# F1-Score: 0.855
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.91      0.86      5508
#          1.0       0.90      0.81      0.85      5873
#
#     accuracy                           0.85     11381
#    macro avg       0.86      0.86      0.85     11381
# weighted avg       0.86      0.85      0.85     11381
#
#
# KNN Similarity Metrics:
#
# KNN Similarity Metrics:
# Precision: 0.811
# Recall: 0.803
# F1-Score: 0.802
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.87      0.81      5508
#          1.0       0.86      0.74      0.79      5873
#
#     accuracy                           0.80     11381
#    macro avg       0.81      0.81      0.80     11381
# weighted avg       0.81      0.80      0.80     11381
#
#
# Logistic Regression Similarity Metrics:
#
# Logistic Regression Similarity Metrics:
# Precision: 0.857
# Recall: 0.852
# F1-Score: 0.852
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.90      0.86      5508
#          1.0       0.90      0.81      0.85      5873
#
#     accuracy                           0.85     11381
#    macro avg       0.86      0.85      0.85     11381
# weighted avg       0.86      0.85      0.85     11381
#
#
# Neural Network Similarity Metrics:
#
# Neural Network Similarity Metrics:
# Precision: 0.824
# Recall: 0.807
# F1-Score: 0.805
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.92      0.82      5508
#          1.0       0.90      0.70      0.79      5873
#
#     accuracy                           0.81     11381
#    macro avg       0.82      0.81      0.81     11381
# weighted avg       0.82      0.81      0.80     11381
#
#
# SVM Similarity Metrics:
#
# SVM Similarity Metrics:
# Precision: 0.866
# Recall: 0.858
# F1-Score: 0.858
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.93      0.86      5508
#          1.0       0.92      0.80      0.85      5873
#
#     accuracy                           0.86     11381
#    macro avg       0.86      0.86      0.86     11381
# weighted avg       0.87      0.86      0.86     11381

# %%
import pandas as pd
from tabulate import tabulate

data = {
    "Model": ["Decision Tree", "KNN", "Logistic Regression", "Neural Network", "SVM"],
    "Precision": [dt_precision, knn_precision, log_precision, nn_precision, svm_precision],
    "Recall": [dt_recall, knn_recall, log_recall, nn_recall, svm_recall],
    "F1-Score": [dt_f1, knn_f1, log_f1, nn_f1, svm_f1]
}

df = pd.DataFrame(data)

print("\nModel Performance Comparison:\n")
print(tabulate(df, headers='keys', tablefmt='pretty'))
# Out:
# Model Performance Comparison:
#
# +---+---------------------+--------------------+--------------------+--------------------+
# |   |        Model        |     Precision      |       Recall       |      F1-Score      |
# +---+---------------------+--------------------+--------------------+--------------------+
# | 0 |    Decision Tree    | 0.8595641955123495 | 0.8548457956242861 | 0.8546704913765496 |
# | 1 |         KNN         | 0.8106048682246364 | 0.8029171426060979 | 0.8023029420004854 |
# | 2 | Logistic Regression | 0.8567339833706853 | 0.8522098233898603 | 0.8520431105026349 |
# | 3 |   Neural Network    | 0.8240772542195237 | 0.8065196379931465 | 0.8047587839044287 |
# | 4 |         SVM         | 0.8660176212520262 | 0.8584482910113347 | 0.8580848457872219 |
# +---+---------------------+--------------------+--------------------+--------------------+

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


model_times = {
    "Model": ["Decision Tree", "KNN", "Logistic Regression", "Neural Network", "SVM"],
    "Training Time (s)": [dt_time, knn_time, lr_time, nn_time, svm_time]
}
time_df = pd.DataFrame(model_times)


plt.figure(figsize=(12, 6))
ax = sns.barplot(x='Model', y='Training Time (s)', data=time_df, palette='viridis')


for i, v in enumerate(time_df["Training Time (s)"]):
    ax.text(i, v + 0.1, f"{v:.2f}s", ha='center', fontweight='bold')


plt.title('Model Training and Tuning Time Comparison', fontsize=16)
plt.xlabel('Model', fontsize=14)
plt.ylabel('Time (seconds)', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\Leong Jing Feng\AppData\Local\Temp\ipykernel_31936\8890684.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Model', y='Training Time (s)', data=time_df, palette='viridis')

# %% [markdown]
# #### **Regressor Model**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Separate LOS and NLOS data
los_data = cleaned_data_top[cleaned_data_top['NLOS'] == 0]
nlos_data = cleaned_data_top[cleaned_data_top['NLOS'] == 1]

# Features (X) and target (y = RANGE)
X_los = los_data[['RXPACC', 'CIR_PWR', 'FP_POWER', 'MAX_NOISE', 'PC3', 'FP_AMP2','PC4','FP_AMP1','FP_AMP3','PC1']]
y_los = los_data['RANGE']

X_nlos = nlos_data[['FP_POWER', 'RXPACC', 'CIR_PWR', 'PREAM_LEN', 'PC3','PC1','PC4','MAX_NOISE','PC2','FP_AMP1']]
y_nlos = nlos_data['RANGE']

# Train-test split (70-30)
X_los_train, X_los_test, y_los_train, y_los_test = train_test_split(X_los, y_los, test_size=0.3, random_state=42)
X_nlos_train, X_nlos_test, y_nlos_train, y_nlos_test = train_test_split(X_nlos, y_nlos, test_size=0.3, random_state=42)

print("LOS training set size:", X_los_train.shape)
print("NLOS training set size:", X_nlos_train.shape)
# Out:
# LOS training set size: (12805, 10)
# NLOS training set size: (13748, 10)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# Function to tune hyperparameters and retrain model with timing
def tune_and_retrain(model, param_grid, X_train, y_train, X_test, y_test):
    start_time = time.time()  
    
    random_search = RandomizedSearchCV(
        model, param_grid, n_iter=10, cv=3, scoring='neg_mean_squared_error', random_state=42, n_jobs=-1
    )
    random_search.fit(X_train, y_train)
    
    best_model = random_search.best_estimator_  # Get best model
    print("Best Hyperparameters:", random_search.best_params_)
    print(f"Best Cross-validation Score (MSE): {abs(random_search.best_score_):.4f}")
    

    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)
    

    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    

    elapsed_time = time.time() - start_time
    print(f"Execution time: {elapsed_time:.2f} seconds")
    
    print(f"Test RMSE after tuning: {rmse:.4f}")
    print(f"Test R² Score after tuning: {r2:.4f}")
    
    return best_model, rmse, r2, elapsed_time  # Return elapsed time as well

# %%
# Hyperparameter grids
param_grids = {
    "Linear Regression": {},  
    
    "Random Forest": {
        "n_estimators": [50, 100, 200, 300],
        "max_depth": [10, 20, 30, None],
        "min_samples_split": [2, 5, 10]
    },
    
    "Support Vector Regressor": {
        "C": [0.1, 1, 10],
        "kernel": ['rbf'],
        "epsilon": [0.01, 0.1, 1]
    },
    
    "Neural Network": {
        "hidden_layer_sizes": [(50,), (100,), (100, 50)],
        "alpha": [0.0001, 0.001, 0.01],
        "max_iter": [500, 1000, 1500]
    },
    
    "Gradient Boosting": {
        "n_estimators": [100, 200, 300],
        "learning_rate": [0.01, 0.1, 0.2],
        "max_depth": [3, 5, 10]
    }
}

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor


models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(random_state=42),
    "Support Vector Regressor": SVR(),
    "Neural Network": MLPRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42)
}


los_results = []
for name, model in models.items():
    print(f"Tuning {name} for LOS path...")
    best_model, rmse, r2, exec_time = tune_and_retrain(model, param_grids[name], X_los_train, y_los_train, X_los_test, y_los_test)
    los_results.append({
        "Model": name, 
        "RMSE": rmse, 
        "R²": r2, 
        "Path": "LOS", 
        "Time (seconds)": exec_time
    })

los_results_df = pd.DataFrame(los_results)
print("\nLOS Path Model Comparison (After Tuning):")
print(los_results_df)
# Out:
# Tuning Linear Regression for LOS path...
# Best Hyperparameters: {}
# Best Cross-validation Score (MSE): 1.4702
# Execution time: 0.03 seconds
# Test RMSE after tuning: 1.2012
# Test R² Score after tuning: 0.4509
# Tuning Random Forest for LOS path...
# C:\Users\Leong Jing Feng\anaconda3\envs\DA_Project\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 300, 'min_samples_split': 5, 'max_depth': None}
# Best Cross-validation Score (MSE): 1.0920
# Execution time: 70.74 seconds
# Test RMSE after tuning: 1.0406
# Test R² Score after tuning: 0.5879
# Tuning Support Vector Regressor for LOS path...
# C:\Users\Leong Jing Feng\anaconda3\envs\DA_Project\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'kernel': 'rbf', 'epsilon': 0.1, 'C': 10}
# Best Cross-validation Score (MSE): 1.4832
# Execution time: 18.26 seconds
# Test RMSE after tuning: 1.1943
# Test R² Score after tuning: 0.4572
# Tuning Neural Network for LOS path...
# Best Hyperparameters: {'max_iter': 500, 'hidden_layer_sizes': (50,), 'alpha': 0.0001}
# Best Cross-validation Score (MSE): 136.2139
# Execution time: 10.71 seconds
# Test RMSE after tuning: 20.6146
# Test R² Score after tuning: -160.7179
# Tuning Gradient Boosting for LOS path...
# Best Hyperparameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.1}
# Best Cross-validation Score (MSE): 1.0917
# Execution time: 36.44 seconds
# Test RMSE after tuning: 1.0451
# Test R² Score after tuning: 0.5843
#
# LOS Path Model Comparison (After Tuning):
#                       Model       RMSE          R² Path  Time (seconds)
# 0         Linear Regression   1.201204    0.450911  LOS        0.031549
# 1             Random Forest   1.040638    0.587894  LOS       70.735411
# 2  Support Vector Regressor   1.194331    0.457176  LOS       18.260812
# 3            Neural Network  20.614583 -160.717936  LOS       10.714395
# 4         Gradient Boosting   1.045116    0.584341  LOS       36.441029

# %%
# Store results
nlos_results = []
for name, model in models.items():
    print(f"Tuning {name} for NLOS path...")
    best_model, rmse, r2, exec_time = tune_and_retrain(model, param_grids[name], X_nlos_train, y_nlos_train, X_nlos_test, y_nlos_test)
    nlos_results.append({
        "Model": name, 
        "RMSE": rmse, 
        "R²": r2, 
        "Path": "NLOS", 
        "Time (seconds)": exec_time
    })

nlos_results_df = pd.DataFrame(nlos_results)
print("\nNLOS Path Model Comparison (After Tuning):")
print(nlos_results_df)
# Out:
# Tuning Linear Regression for NLOS path...
# Best Hyperparameters: {}
# Best Cross-validation Score (MSE): 3.7439
# Execution time: 0.03 seconds
# Test RMSE after tuning: 1.9609
# Test R² Score after tuning: 0.3903
# Tuning Random Forest for NLOS path...
# C:\Users\Leong Jing Feng\anaconda3\envs\DA_Project\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'n_estimators': 300, 'min_samples_split': 5, 'max_depth': 20}
# Best Cross-validation Score (MSE): 3.2795
# Execution time: 74.03 seconds
# Test RMSE after tuning: 1.8367
# Test R² Score after tuning: 0.4651
# Tuning Support Vector Regressor for NLOS path...
# C:\Users\Leong Jing Feng\anaconda3\envs\DA_Project\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Best Hyperparameters: {'kernel': 'rbf', 'epsilon': 1, 'C': 10}
# Best Cross-validation Score (MSE): 3.5704
# Execution time: 17.01 seconds
# Test RMSE after tuning: 1.9149
# Test R² Score after tuning: 0.4186
# Tuning Neural Network for NLOS path...
# Best Hyperparameters: {'max_iter': 500, 'hidden_layer_sizes': (50,), 'alpha': 0.0001}
# Best Cross-validation Score (MSE): 46.9516
# Execution time: 13.41 seconds
# Test RMSE after tuning: 6.8283
# Test R² Score after tuning: -6.3928
# Tuning Gradient Boosting for NLOS path...
# Best Hyperparameters: {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.1}
# Best Cross-validation Score (MSE): 3.3506
# Execution time: 33.94 seconds
# Test RMSE after tuning: 1.8583
# Test R² Score after tuning: 0.4525
#
# NLOS Path Model Comparison (After Tuning):
#                       Model      RMSE        R²  Path  Time (seconds)
# 0         Linear Regression  1.960874  0.390346  NLOS        0.030530
# 1             Random Forest  1.836726  0.465099  NLOS       74.025089
# 2  Support Vector Regressor  1.914892  0.418603  NLOS       17.014745
# 3            Neural Network  6.828290 -6.392786  NLOS       13.410899
# 4         Gradient Boosting  1.858276  0.452474  NLOS       33.937599

# %%
import matplotlib.pyplot as plt
import seaborn as sns


combined_results = pd.concat([los_results_df, nlos_results_df])


plt.figure(figsize=(12, 6))
sns.barplot(data=combined_results, x='Model', y='RMSE', hue='Path')
plt.title('RMSE Comparison After Randomized Hyperparameter Tuning')
plt.ylabel('Root Mean Square Error (RMSE)')
plt.xticks(rotation=45)
plt.legend(title='Path')
plt.show()


plt.figure(figsize=(12, 6))
sns.barplot(data=combined_results, x='Model', y='R²', hue='Path')
plt.title('R² Score Comparison After Randomized Hyperparameter Tuning')
plt.ylabel('R² Score')
plt.xticks(rotation=45)
plt.legend(title='Path')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


r2_min_limit = -2  


combined_results_clipped = combined_results.copy()
combined_results_clipped.loc[
    (combined_results_clipped['Model'] == 'Neural Network') & (combined_results_clipped['R²'] < r2_min_limit),
    'R²'
] = r2_min_limit  


plt.figure(figsize=(12, 6))
ax = sns.barplot(data=combined_results_clipped, x='Model', y='R²', hue='Path')


plt.title('R² Score Comparison After Randomized Hyperparameter Tuning')
plt.ylabel('R² Score')
plt.xticks(rotation=45)
plt.legend(title='Path')


for i, row in combined_results.iterrows():
    if row['Model'] == 'Neural Network' and row['R²'] < r2_min_limit:
        plt.text(i, r2_min_limit + 0.1, f"{row['R²']:.2f}", color='red', ha='center', fontsize=10)


plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot execution time
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=combined_results, x='Model', y='Time (seconds)', hue='Path')


for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                fontsize=10, color='black', 
                xytext=(0, 5), 
                textcoords='offset points')

plt.title('Execution Time Comparison After Randomized Hyperparameter Tuning')
plt.ylabel('Time (seconds)')
plt.xticks(rotation=45)
plt.legend(title='Path')
plt.tight_layout()
plt.show()

# %%
# Calculate RMSE and R² differences between LOS and NLOS for each model
los_rmse = los_results_df.set_index('Model')['RMSE']
nlos_rmse = nlos_results_df.set_index('Model')['RMSE']

rmse_diff = (los_rmse - nlos_rmse).abs()
print("\nAbsolute RMSE Differences Between LOS and NLOS:")
print(rmse_diff)

los_r2 = los_results_df.set_index('Model')['R²']
nlos_r2 = nlos_results_df.set_index('Model')['R²']

r2_diff = (los_r2 - nlos_r2).abs()
print("\nAbsolute R² Differences Between LOS and NLOS:")
print(r2_diff)
# Out:
# Absolute RMSE Differences Between LOS and NLOS:
# Model
# Linear Regression            0.759670
# Random Forest                0.796088
# Support Vector Regressor     0.720561
# Neural Network              13.786294
# Gradient Boosting            0.813161
# Name: RMSE, dtype: float64
#
# Absolute R² Differences Between LOS and NLOS:
# Model
# Linear Regression             0.060565
# Random Forest                 0.122795
# Support Vector Regressor      0.038574
# Neural Network              154.325150
# Gradient Boosting             0.131867
# Name: R², dtype: float64

# %%
# Visualize RMSE Differences
rmse_diff_df = rmse_diff.reset_index()
rmse_diff_df.columns = ['Model', 'RMSE Difference']

plt.figure(figsize=(12, 6))
sns.barplot(data=rmse_diff_df, x='Model', y='RMSE Difference', color='crimson')
plt.title('RMSE Dissimilarity Between LOS and NLOS')
plt.ylabel('Absolute RMSE Difference')
plt.xticks(rotation=45)
plt.show()

# Visualize R² Differences
r2_diff_df = r2_diff.reset_index()
r2_diff_df.columns = ['Model', 'R² Difference']

plt.figure(figsize=(12, 6))
sns.barplot(data=r2_diff_df, x='Model', y='R² Difference', color='purple')
plt.title('R² Dissimilarity Between LOS and NLOS')
plt.ylabel('Absolute R² Difference')
plt.xticks(rotation=45)
plt.show()

# %%
comprehensive_data = {
    "Model": los_rmse.index.tolist(),
    "LOS RMSE": los_rmse.values,
    "NLOS RMSE": nlos_rmse.values,
    "RMSE Diff": rmse_diff.values,
    "LOS R²": los_r2.values,
    "NLOS R²": nlos_r2.values,
    "R² Diff": r2_diff.values
}
comparison_df = pd.DataFrame(comprehensive_data)


print("\nComprehensive LOS vs NLOS Comparison:\n")
print(tabulate(comparison_df, headers='keys', tablefmt='pretty', showindex=False))
# Out:
# Comprehensive LOS vs NLOS Comparison:
#
# +--------------------------+--------------------+--------------------+--------------------+---------------------+---------------------+---------------------+
# |          Model           |      LOS RMSE      |     NLOS RMSE      |     RMSE Diff      |       LOS R²        |       NLOS R²       |       R² Diff       |
# +--------------------------+--------------------+--------------------+--------------------+---------------------+---------------------+---------------------+
# |    Linear Regression     | 1.2012042046195601 | 1.9608740260118134 | 0.7596698213922533 | 0.45091099030140513 | 0.39034566215093036 | 0.06056532815047477 |
# |      Random Forest       | 1.0406383987762227 | 1.8367261638225116 | 0.796087765046289  | 0.5878941706845707  | 0.46509937474241947 | 0.12279479594215126 |
# | Support Vector Regressor | 1.1943312995626116 | 1.9148920591223828 | 0.7205607595597712 | 0.4571764367189396  | 0.41860287891046977 | 0.03857355780846983 |
# |      Neural Network      | 20.614583426997186 | 6.828289714590899  | 13.786293712406287 | -160.71793608234185 | -6.392786416205821  | 154.32514966613604  |
# |    Gradient Boosting     | 1.0451155705170996 | 1.8582764574522241 | 0.8131608869351246 | 0.5843405105004141  | 0.45247376900616265 | 0.13186674149425148 |
# +--------------------------+--------------------+--------------------+--------------------+---------------------+---------------------+---------------------+
